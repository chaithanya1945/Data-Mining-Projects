# %% [markdown]
# # Project 1 / Data Manipulation, Pandas and Distance Metrics

# %% [markdown]
# This Project is worth up to 15 POINTS to your grade total if you do it and turn it in on time.

# %% [markdown]
# ## OBJECTIVE
# * Learn how to use Pandas for data ingest, manipulation and summarization.
# * Learn to perform a simple exploratory data analysis to plot data and visualize outcomes.
# * Understand how to use and interpret Pearson-_r_ for correlation.
# * Implement $k$-Nearest Neighbors and see a distance metric in action on real data.

# %% [markdown]
# ## WHAT TO TURN IN
#
# You are being encouraged to turn the assignment in using the provided Jupyter Notebook.  To do so, clone the repository and modify the `.ipynb` file in the `Projecet/01` directory.
#
# Turn in a copy of a ipynb file OR a PDF or Word Document to Blackboard with the answers to the questions labeled with the &#167; sign.

# %% [markdown]
# ## RESOURCES
#
# ### Datasets
#
# | Dataset | Summary | Size |
# |---------|---------|------|
# |[Salt Lake City Water Usage Jan-July 2016](http://www.civicdata.io/dataset/slc_water_usage_1/resource/a2bc8285-d9ef-45ca-ae86-bf735bc5011a) | Real data that includes water usage for various property types, connection counts, etc. | > 40K instances, < 10 features |
# |[Sacramento Real Estate transactions, May 15-21, 2008](http://samplecsvs.s3.amazonaws.com/Sacramentorealestatetransactions.csv).  Also found [archived here in the repo](./Sacramentorealestatetransactions.csv).| Sacramento transcation data from real estate properties sold in a single week in 2008.  Includes latitude, longitude, prices, addresses, and basic property characteristics (# beds, square footage, etc.) | > 900 instances, < 10 features |
#
# ### Pandas
#
# http://pandas.pydata.org/
#
# ### Jupyter Notebooks
#
# http://jupyter.org
#
# ### Code
#
# You might need to use the following at the beginning of your Jupyter notebook:
# ```python
# %matplotlib inline
# import numpy as np
# import requests
# import pandas as pd
# import numpy as np
# ```

# %% [markdown]
# ## HOW TO COMPLETE THIS PROJECT / PROJECT DETAILS

# %% [markdown]
# ## PART 1 / Python Pandas
#
# For this part you will need to load and analyze data using [Pandas](http://pandas.pydata.org).
#
# Familiarize yourself with the dataset from the [spatialkey.com](https://support.spatialkey.com/spatialkey-sample-csv-data/) website.  In particular, we will be working with the dataset here:
# ![sacramento dataset](./spatialkey_screenshot01.PNG)

# %% [markdown]
# ###  &#167; Write the Python code to load the [CSV file from spatialkey](http://samplecsvs.s3.amazonaws.com/Sacramentorealestatetransactions.csv) directly into a Pandas dataframe.
#  * You may need to familiarize yourself with the [IO Tools](http://pandas.pydata.org/pandas-docs/stable/io.html) functions of Pandas.
#  * Load the file to your local file system where the running code exists (e.g. the CSV file should exist in the same location as your code or notebook).
#  * Turn in the fragment of code that does this.

# %%
import matplotlib.pyplot as plt
import numpy as np
from StringIO import StringIO
import math
from scipy import stats  as sp
import pandas as pd
import numpy as np
def ufo():
    filesac = pd.read_csv('https://raw.githubusercontent.com/kmsaumcis/mcis6273_f16_datamining/master/HOMEWORK/01/Sacramentorealestatetransactions.csv')
    return(filesac)
ufo()
# Out:
#                               street             city    zip state  beds  \
# 0                       3526 HIGH ST       SACRAMENTO  95838    CA     2
# 1                        51 OMAHA CT       SACRAMENTO  95823    CA     3
# 2                     2796 BRANCH ST       SACRAMENTO  95815    CA     2
# 3                   2805 JANETTE WAY       SACRAMENTO  95815    CA     2
# 4                    6001 MCMAHON DR       SACRAMENTO  95824    CA     2
# 5                 5828 PEPPERMILL CT       SACRAMENTO  95841    CA     3
# 6                6048 OGDEN NASH WAY       SACRAMENTO  95842    CA     3
# 7                      2561 19TH AVE       SACRAMENTO  95820    CA     3
# 8    11150 TRINITY RIVER DR Unit 114   RANCHO CORDOVA  95670    CA     2
# 9                       7325 10TH ST        RIO LINDA  95673    CA     3
# 10                  645 MORRISON AVE       SACRAMENTO  95838    CA     3
# 11                     4085 FAWN CIR       SACRAMENTO  95823    CA     3
# 12                   2930 LA ROSA RD       SACRAMENTO  95815    CA     1
# 13                     2113 KIRK WAY       SACRAMENTO  95822    CA     3
# 14               4533 LOCH HAVEN WAY       SACRAMENTO  95842    CA     2
# 15                    7340 HAMDEN PL       SACRAMENTO  95842    CA     2
# 16                       6715 6TH ST        RIO LINDA  95673    CA     2
# 17           6236 LONGFORD DR Unit 1   CITRUS HEIGHTS  95621    CA     2
# 18                   250 PERALTA AVE       SACRAMENTO  95833    CA     2
# 19                   113 LEEWILL AVE        RIO LINDA  95673    CA     3
# 20                6118 STONEHAND AVE   CITRUS HEIGHTS  95621    CA     3
# 21                 4882 BANDALIN WAY       SACRAMENTO  95823    CA     4
# 22                   7511 OAKVALE CT  NORTH HIGHLANDS  95660    CA     4
# 23                      9 PASTURE CT       SACRAMENTO  95834    CA     3
# 24                3729 BAINBRIDGE DR  NORTH HIGHLANDS  95660    CA     3
# 25                3828 BLACKFOOT WAY         ANTELOPE  95843    CA     3
# 26                   4108 NORTON WAY       SACRAMENTO  95820    CA     3
# 27                  1469 JANRICK AVE       SACRAMENTO  95832    CA     3
# 28                     9861 CULP WAY       SACRAMENTO  95827    CA     4
# 29             7825 CREEK VALLEY CIR       SACRAMENTO  95828    CA     3
# ..                               ...              ...    ...   ...   ...
# 955                  2100 BEATTY WAY        ROSEVILLE  95747    CA     3
# 956              6920 GILLINGHAM WAY  NORTH HIGHLANDS  95660    CA     3
# 957                 82 WILDFLOWER DR             GALT  95632    CA     3
# 958                  8652 BANTON CIR        ELK GROVE  95624    CA     4
# 959              8428 MISTY PASS WAY         ANTELOPE  95843    CA     3
# 960                7958 ROSEVIEW WAY       SACRAMENTO  95828    CA     3
# 961                    9020 LUKEN CT        ELK GROVE  95624    CA     3
# 962              7809 VALLECITOS WAY       SACRAMENTO  95828    CA     3
# 963               8445 OLD AUBURN RD   CITRUS HEIGHTS  95610    CA     3
# 964                  10085 ATKINS DR        ELK GROVE  95757    CA     3
# 965              9185 CERROLINDA CIR        ELK GROVE  95758    CA     3
# 966                 9197 CORTINA CIR        ROSEVILLE  95678    CA     3
# 967                  5429 HESPER WAY       CARMICHAEL  95608    CA     4
# 968                 1178 WARMWOOD CT             GALT  95632    CA     4
# 969                    4900 ELUDE CT       SACRAMENTO  95842    CA     4
# 970                    3557 SODA WAY       SACRAMENTO  95834    CA     0
# 971             3528 SAINT GEORGE DR       SACRAMENTO  95821    CA     3
# 974  38.703056 -121.235221
# 975  38.389756 -121.446246
# 976  38.897814 -121.324691
# 977  38.467936 -121.445477
# 978  38.445342 -121.441504
# 979  38.417382 -121.484325
# 980  38.457679 -121.359620
# 981  38.499893 -121.458890
# 982  38.708824 -121.256803
# 983  38.417000 -121.397424
# 984  38.655245 -121.075915
#
# [985 rows x 12 columns]

# %% [markdown]
# ### &#167;  Compute the price per square foot for all properties.  Add this data back into the dataframe.
#  * See the documentation on [concatening objects](http://pandas.pydata.org/pandas-docs/stable/merging.html#concatenating-objects).
#  * Turn in the code that does this, and show the results of `head()` and `tail()` on the new dataframe.

# %%
ufo = pd.read_csv('https://raw.githubusercontent.com/kmsaumcis/mcis6273_f16_datamining/master/HOMEWORK/01/Sacramentorealestatetransactions.csv')

# %%
ufo['value'] = ufo.price/ufo.sq__ft

# %%
ufo
# Out:
#                               street             city    zip state  beds  \
# 0                       3526 HIGH ST       SACRAMENTO  95838    CA     2
# 1                        51 OMAHA CT       SACRAMENTO  95823    CA     3
# 2                     2796 BRANCH ST       SACRAMENTO  95815    CA     2
# 3                   2805 JANETTE WAY       SACRAMENTO  95815    CA     2
# 4                    6001 MCMAHON DR       SACRAMENTO  95824    CA     2
# 5                 5828 PEPPERMILL CT       SACRAMENTO  95841    CA     3
# 6                6048 OGDEN NASH WAY       SACRAMENTO  95842    CA     3
# 7                      2561 19TH AVE       SACRAMENTO  95820    CA     3
# 8    11150 TRINITY RIVER DR Unit 114   RANCHO CORDOVA  95670    CA     2
# 9                       7325 10TH ST        RIO LINDA  95673    CA     3
# 10                  645 MORRISON AVE       SACRAMENTO  95838    CA     3
# 11                     4085 FAWN CIR       SACRAMENTO  95823    CA     3
# 12                   2930 LA ROSA RD       SACRAMENTO  95815    CA     1
# 13                     2113 KIRK WAY       SACRAMENTO  95822    CA     3
# 14               4533 LOCH HAVEN WAY       SACRAMENTO  95842    CA     2
# 15                    7340 HAMDEN PL       SACRAMENTO  95842    CA     2
# 16                       6715 6TH ST        RIO LINDA  95673    CA     2
# 17           6236 LONGFORD DR Unit 1   CITRUS HEIGHTS  95621    CA     2
# 18                   250 PERALTA AVE       SACRAMENTO  95833    CA     2
# 19                   113 LEEWILL AVE        RIO LINDA  95673    CA     3
# 20                6118 STONEHAND AVE   CITRUS HEIGHTS  95621    CA     3
# 21                 4882 BANDALIN WAY       SACRAMENTO  95823    CA     4
# 22                   7511 OAKVALE CT  NORTH HIGHLANDS  95660    CA     4
# 23                      9 PASTURE CT       SACRAMENTO  95834    CA     3
# 24                3729 BAINBRIDGE DR  NORTH HIGHLANDS  95660    CA     3
# 25                3828 BLACKFOOT WAY         ANTELOPE  95843    CA     3
# 26                   4108 NORTON WAY       SACRAMENTO  95820    CA     3
# 27                  1469 JANRICK AVE       SACRAMENTO  95832    CA     3
# 28                     9861 CULP WAY       SACRAMENTO  95827    CA     4
# 29             7825 CREEK VALLEY CIR       SACRAMENTO  95828    CA     3
# ..                               ...              ...    ...   ...   ...
# 955                  2100 BEATTY WAY        ROSEVILLE  95747    CA     3
# 9    38.700909 -121.442979   86.332461
# 10   38.637663 -121.451520  110.350935
# 11   38.470746 -121.458918   82.428239
# 12   38.618698 -121.435833  122.677382
# 13   38.482215 -121.492603  105.394118
# 14   38.672914 -121.359340  106.409002
# 15   38.700051 -121.351278   97.619048
# 16   38.689591 -121.452239  134.197867
# 17   38.679776 -121.314089  146.226415
# 18   38.612099 -121.469095  204.081633
# 19   38.689999 -121.463220   89.697640
# 20   38.707851 -121.320707  109.123435
# 21   38.468173 -121.444071   92.311512
# 22   38.702792 -121.382210   99.193548
# 23   38.628631 -121.488097   77.514054
# 24   38.701499 -121.376220  138.734739
# 25   38.709740 -121.373770  116.397059
# 26   38.537526 -121.478315  132.171340
# 27   38.476472 -121.501711  115.281501
# 28   38.558423 -121.327948   95.072464
# 29   38.472122 -121.404199  105.769231
# ..         ...         ...         ...
# 955  38.737882 -121.308142  151.896426
# 956  38.694279 -121.373395  159.021374
# 957  38.259708 -121.311616  165.885103
# 958  38.444000 -121.370993  121.551724
# 959  38.722959 -121.347115  139.749506
# 960  38.467836 -121.410366  146.896552
# 961  38.451398 -121.366614  152.542373
# 962  38.508217 -121.411207  243.266892
# 963  38.715423 -121.246743  116.365569
# 964  38.390893 -121.437821  168.812596
# 965  38.424497 -121.426595  155.148096
# 966  38.793152 -121.290025         inf
# 967  38.665104 -121.315901  166.793025
# 968  38.289544 -121.284607  124.293785
# 969  38.696740 -121.350519  137.062077
# 970  38.631026 -121.501879         inf
# 971  38.629468 -121.376445  215.384615
# 972  38.703550 -121.375103  233.595833
# 973  38.697570 -120.995739         inf
# 974  38.703056 -121.235221  154.532967
# 975  38.389756 -121.446246  157.241379
# 976  38.897814 -121.324691  168.650221
# 977  38.467936 -121.445477  172.686230
# 978  38.445342 -121.441504  134.110787
# 979  38.417382 -121.484325  182.250396
# 980  38.457679 -121.359620  101.940789
# 981  38.499893 -121.458890  158.429248
# 982  38.708824 -121.256803  193.256579
# 983  38.417000 -121.397424  139.644510
# 984  38.655245 -121.075915  173.082232
#
# [985 rows x 13 columns]

# %% [markdown]
# ### &#167;  Provide three data points from the original dataset that give you reason to be concerned about the some of the properties with unusual price per square foot data.
#  * Learn about [summarizing your data](http://pandas.pydata.org/pandas-docs/stable/basics.html#descriptive-statistics) and [sorting](http://pandas.pydata.org/pandas-docs/stable/basics.html#by-values).
#  * Turn in the rows of those three data points and 1 to 3 sentences discussing your concerns.

# %%
ufo['avg'] = ufo.mean(axis=1)

# %%
ufo
# Out:
#                               street             city    zip state  beds  \
# 0                       3526 HIGH ST       SACRAMENTO  95838    CA     2
# 1                        51 OMAHA CT       SACRAMENTO  95823    CA     3
# 2                     2796 BRANCH ST       SACRAMENTO  95815    CA     2
# 3                   2805 JANETTE WAY       SACRAMENTO  95815    CA     2
# 4                    6001 MCMAHON DR       SACRAMENTO  95824    CA     2
# 5                 5828 PEPPERMILL CT       SACRAMENTO  95841    CA     3
# 6                6048 OGDEN NASH WAY       SACRAMENTO  95842    CA     3
# 7                      2561 19TH AVE       SACRAMENTO  95820    CA     3
# 8    11150 TRINITY RIVER DR Unit 114   RANCHO CORDOVA  95670    CA     2
# 9                       7325 10TH ST        RIO LINDA  95673    CA     3
# 10                  645 MORRISON AVE       SACRAMENTO  95838    CA     3
# 11                     4085 FAWN CIR       SACRAMENTO  95823    CA     3
# 12                   2930 LA ROSA RD       SACRAMENTO  95815    CA     1
# 13                     2113 KIRK WAY       SACRAMENTO  95822    CA     3
# 14               4533 LOCH HAVEN WAY       SACRAMENTO  95842    CA     2
# 15                    7340 HAMDEN PL       SACRAMENTO  95842    CA     2
# 16                       6715 6TH ST        RIO LINDA  95673    CA     2
# 17           6236 LONGFORD DR Unit 1   CITRUS HEIGHTS  95621    CA     2
# 18                   250 PERALTA AVE       SACRAMENTO  95833    CA     2
# 19                   113 LEEWILL AVE        RIO LINDA  95673    CA     3
# 20                6118 STONEHAND AVE   CITRUS HEIGHTS  95621    CA     3
# 21                 4882 BANDALIN WAY       SACRAMENTO  95823    CA     4
# 22                   7511 OAKVALE CT  NORTH HIGHLANDS  95660    CA     4
# 23                      9 PASTURE CT       SACRAMENTO  95834    CA     3
# 24                3729 BAINBRIDGE DR  NORTH HIGHLANDS  95660    CA     3
# 25                3828 BLACKFOOT WAY         ANTELOPE  95843    CA     3
# 26                   4108 NORTON WAY       SACRAMENTO  95820    CA     3
# 27                  1469 JANRICK AVE       SACRAMENTO  95832    CA     3
# 28                     9861 CULP WAY       SACRAMENTO  95827    CA     4
# 29             7825 CREEK VALLEY CIR       SACRAMENTO  95828    CA     3
# ..                               ...              ...    ...   ...   ...
# 955                  2100 BEATTY WAY        ROSEVILLE  95747    CA     3
# 956              6920 GILLINGHAM WAY  NORTH HIGHLANDS  95660    CA     3
# 957                 82 WILDFLOWER DR             GALT  95632    CA     3
# 958                  8652 BANTON CIR        ELK GROVE  95624    CA     4
# 959              8428 MISTY PASS WAY         ANTELOPE  95843    CA     3
# 960                7958 ROSEVIEW WAY       SACRAMENTO  95828    CA     3
# 961                    9020 LUKEN CT        ELK GROVE  95624    CA     3
# 962              7809 VALLECITOS WAY       SACRAMENTO  95828    CA     3
# 963               8445 OLD AUBURN RD   CITRUS HEIGHTS  95610    CA     3
# 964                  10085 ATKINS DR        ELK GROVE  95757    CA     3
# 965              9185 CERROLINDA CIR        ELK GROVE  95758    CA     3
# 966                 9197 CORTINA CIR        ROSEVILLE  95678    CA     3
# 967                  5429 HESPER WAY       CARMICHAEL  95608    CA     4
# 968                 1178 WARMWOOD CT             GALT  95632    CA     4
# 969                    4900 ELUDE CT       SACRAMENTO  95842    CA     4
# 970                    3557 SODA WAY       SACRAMENTO  95834    CA     0
# 971             3528 SAINT GEORGE DR       SACRAMENTO  95821    CA     3
# 972                7381 WASHBURN WAY  NORTH HIGHLANDS  95660    CA     3
# 973             2181 WINTERHAVEN CIR     CAMERON PARK  95682    CA     3
# 974                 7540 HICKORY AVE       ORANGEVALE  95662    CA     3
# 975              5024 CHAMBERLIN CIR        ELK GROVE  95757    CA     3
# 976                2400 INVERNESS DR          LINCOLN  95648    CA     3
# 977                  5 BISHOPGATE CT       SACRAMENTO  95823    CA     4
# 29   38.472122 -121.404199  105.769231  2.863798e+04
# ..         ...         ...         ...           ...
# 955  38.737882 -121.308142  151.896426  3.818029e+04
# 956  38.694279 -121.373395  159.021374  3.817104e+04
# 957  38.259708 -121.311616  165.885103  3.829110e+04
# 958  38.444000 -121.370993  121.551724  3.861358e+04
# 959  38.722959 -121.347115  139.749506  3.867777e+04
# 960  38.467836 -121.410366  146.896552  3.879337e+04
# 961  38.451398 -121.366614  152.542373  3.913933e+04
# 962  38.508217 -121.411207  243.266892  3.911267e+04
# 963  38.715423 -121.246743  116.365569  3.956635e+04
# 964  38.390893 -121.437821  168.812596  3.961797e+04
# 965  38.424497 -121.426595  155.148096  3.965664e+04
# 966  38.793152 -121.290025         inf           inf
# 967  38.665104 -121.315901  166.793025  3.962714e+04
# 968  38.289544 -121.284607  124.293785  3.968116e+04
# 969  38.696740 -121.350519  137.062077  4.006618e+04
# 970  38.631026 -121.501879         inf           inf
# 971  38.629468 -121.376445  215.384615  4.012470e+04
# 972  38.703550 -121.375103  233.595833  4.012837e+04
# 973  38.697570 -120.995739         inf           inf
# 974  38.703056 -121.235221  154.532967  4.027425e+04
# 975  38.389756 -121.446246  157.241379  4.066077e+04
# 976  38.897814 -121.324691  168.650221  4.076553e+04
# 977  38.467936 -121.445477  172.686230  4.084346e+04
# 978  38.445342 -121.441504  134.110787  4.094939e+04
# 979  38.417382 -121.484325  182.250396  4.089052e+04
# 980  38.457679 -121.359620  101.940789  4.132000e+04
# 981  38.499893 -121.458890  158.429248  4.142256e+04
# 982  38.708824 -121.256803  193.256579  4.149271e+04
# 983  38.417000 -121.397424  139.644510  4.160083e+04
# 984  38.655245 -121.075915  173.082232  4.161971e+04
#
# [985 rows x 14 columns]

# %%
ufo.describe()
# Out:
#                 zip        beds       baths       sq__ft          price  \
# count    985.000000  985.000000  985.000000   985.000000     985.000000
# mean   95750.697462    2.911675    1.776650  1314.916751  234144.263959
# std       85.176072    1.307932    0.895371   853.048243  138365.839085
# min    95603.000000    0.000000    0.000000     0.000000    1551.000000
# 25%    95660.000000    2.000000    1.000000   952.000000  145000.000000
# 50%    95762.000000    3.000000    2.000000  1304.000000  213750.000000
# 75%    95828.000000    4.000000    2.000000  1718.000000  300000.000000
# max    95864.000000    8.000000    5.000000  5822.000000  884790.000000
#
#          latitude   longitude       value           avg
# count  985.000000  985.000000  985.000000  9.850000e+02
# mean    38.607732 -121.355982         inf           inf
# std      0.145433    0.138278         NaN           NaN
# min     38.241514 -121.551704    0.343525  1.292871e+04
# 25%     38.482717 -121.446127  114.142628  3.231153e+04
# 50%     38.626582 -121.376220  149.253731  4.132000e+04
# 75%     38.695589 -121.295778  213.178295  6.107555e+04
# max     39.020808 -120.597599         inf           inf

# %%
print "in the given data that shows there are inf values in which in the mean values and also in the std and when we calacute the max value for the price per squre feet the value is nan this difficulte for to show the avg prie per squre feet"
# Out:
# in the given data that shows there are inf values in which in the mean values and also in the std and when we calacute the max value for the price per squre feet the value is nan this difficulte for to show the avg prie per squre feet

# %% [markdown]
# ### &#167;  Use a scatter plot to plot the sale price to the square feet.
#
# ### &#167;  Do the same for number of beds to sale price.
# * You will need to learn about [scatter plots](http://pandas.pydata.org/pandas-docs/stable/basics.html#descriptive-statistics) to complete these.
# * For both, turn in the scatter plot &#emdash; if you're using Jupyter, just leave the plots inline.

# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import requests
import pandas as pd
import numpy as np
from StringIO import StringIO
ufo = pd.read_csv('https://raw.githubusercontent.com/kmsaumcis/mcis6273_f16_datamining/master/HOMEWORK/01/Sacramentorealestatetransactions.csv')
ufo.plot(kind='scatter', x='sq__ft', y='price')

# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import requests
import pandas as pd
import numpy as np
from StringIO import StringIO
ufo = pd.read_csv('https://raw.githubusercontent.com/kmsaumcis/mcis6273_f16_datamining/master/HOMEWORK/01/Sacramentorealestatetransactions.csv')
ufo.plot(kind='scatter', x='beds', y='price')

# %% [markdown]
# ### &#167; Explore the distribution of properties by number of beds.  Plot this using `plot()`
# * Learn about that function [here](http://pandas.pydata.org/pandas-docs/stable/visualization.html).

# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import requests
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/chaithanya1945/hmwork/master/a2bc8285-d9ef-45ca-ae86-bf735bc5011a.csv')
df.hist(column="consumption", by="descr")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0B29B5B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0BD206B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0BD5BE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0BBB9B70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0BA63510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0BE1E090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0BE9B850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0D6E3ED0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0D7A8690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0D7E2D10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0D817C30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0D8E92D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0D827D70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0D9660F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0D9E5770>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0DA5ABB0>]], dtype=object)

# %% [markdown]
# ## PART 2 / Distance metrics and _k_-Nearest Neighbor
#
# ### &#167; Implement the _k_-Nearest Neighbor algorithm in Python using the Euclidean distance metric.
#
# The _k_-Nearest Neighbor algorithm is a very simple _lazy learning_ algorithm.  It computes $k$ neigbors given a data point $d_i$ (vector) from the set of all data $D = \{d_1, d_2, \ldots, d_i, \ldots, d_n\}$.
#
#
# #### 1. Implement the function `d_euclidean(v1, v2)` that takes 2 arguments v1 and v2 which are the vectors you will be comparing from your dataset.
#
# You will be turning in the implementation of two functions.  The first is the Euclidean distance function, which is trivial to implement.  Recall Euclidean distance $d_{\mathrm{euclidean}}$ is defined by, given two vectors $v_1$ and $v_2$ of length $n$ :
#
# $$
# d_{\mathrm{euclidean}} = \sqrt{ {\sum_{i=1}^n \big({v_1}_i - {v_2}_i\big)}^2 }
# $$
#
# You are free to use the implementation in the notes, but please make sure you actually cite it appropriately if you copy it verbatim!
#
# #### 2. Implement the function `knn_euclidean(k, v, d)`that takes two arguments, the number of neighbors to return _k_ the data vector _v_ and the entire dataset _d_.
#
# The algorithm will do the following:
# 1. compute the distance between $v$ and all vectors in $d$ (with $v$ removed, if you like, but the distance between $v$ and itself will be ... 0!).  You will use the function from part 1 `d_euclidean`.
# 2. sort the distances of all vectors in descending order with the closest (lowest) distances first.
# 3. return the _k_ top neighbors
#
# Your Python code might look something like this:
#
# #### What you will turn in:
#
# * Turn in the code for the two functions implemented in Python.
# * Use the templates below :
#
# ```python
#
# # assume v1 and v2 are python tuples
# def d_euclidean(v1, v2):
#     return # the calculation of the euclidean distance
#
#
# # implement the knn algorithm as defined above
# def knn_euclidean(k, v, all_v):
#
#     # compute all the distances between v and d_v in all_v
#     for d_v in all_v:
#         d_euclidean(d_v, v)
#
#     # store the distances, sort and return k of them
#
#     # the rest of your implementation
#
#     return # the top k vectors sorted
#
# ```

# %% [markdown]
# ### &#167; Produce the distance table using your version of _k_-NN for all properties.
#
# *  To make things easier, please reduce the data vector to just beds, bath, square footage, price, latitude and longitude.
# * You can use the street as the index.  Your final output will look something like this:
#
#
# <div class="tg-wrap"><table>
#   <tr>
#     <td></td>
#     <td>3526 HIGH ST</td>
#     <td>51 OMAHA CT</td>
#     <td>C2796 BRANCH ST</td>
#     <td>D2805 JANETTE WAY</td>
#   </tr>
#   <tr>
#     <td>3526 HIGH ST</td>
#     <td>0</td>
#     <td></td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>51 OMAHA CT</td>
#     <td>0.25<br></td>
#     <td>0</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>2796 BRANCH ST</td>
#     <td>0.25</td>
#     <td>0.25</td>
#     <td>0</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>2805 JANETTE WAY</td>
#     <td>0.25</td>
#     <td>0.25</td>
#     <td>0.25</td>
#     <td>0</td>
#   </tr>
# </table></div>
#
#
# ### &#167; Compute the 4-NN and 5-NN to the following properties:
#
# - 4882 BANDALIN WAY
# - 7511 OAKVALE CT
# * 7731 MASTERS ST
# * 4925 PERCHERON DR
# * 4727 SAVOIE WAY
# * 3228 BAGGAN CT
# * 8515 DARTFORD DR
# * 2460 EL ROCCO WAY
# * 5840 WALERGA RD
# * 923 FULTON AVE
# * 4030 BROADWAY
# * 6485 LAGUNA MIRAGE LN
# * 8758 LEMAS RD
# * 1140 EDMONTON DR
# * 1890 GENEVA PL
#
# Turn in the table that has each property address and the addresses of the 4-NN and 5-NN properties.

# %%
filesac = pd.read_csv('https://raw.githubusercontent.com/kmsaumcis/mcis6273_f16_datamining/master/HOMEWORK/01/Sacramentorealestatetransactions.csv')

# %%
def my_knn(vec1, vec2):
    d = math.sqrt((vec1.latitude-vec2.latitude)*(vec1.latitude-vec2.latitude)+(vec1.longitude-vec2.longitude)*(vec1.longitude-vec2.longitude))
    return (d)

# %%
def table(filesac):
    table = pd.DataFrame()
    for i in range (0,len(filesac.index)):
        col=pd.Series()
        for j in range (i,len(filesac.index)):
            series1=filesac.loc[i]
            series2=filesac.loc[j]
            d = my_knn(series1,series2)
            col = col.set_value(j,d)
        table[i]=col
    return(table)

# %%
table(filesac)
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.000000       NaN       NaN       NaN       NaN       NaN       NaN
# 1    0.153059  0.000000       NaN       NaN       NaN       NaN       NaN
# 2    0.016293  0.139990  0.000000       NaN       NaN       NaN       NaN
# 3    0.015670  0.138172  0.004918  0.000000       NaN       NaN       NaN
# 4    0.112447  0.040844  0.099164  0.097424  0.000000       NaN       NaN
# 5    0.111376  0.210705  0.124192  0.120370  0.179274  0.000000       NaN
# 6    0.096915  0.217721  0.111814  0.108849  0.182680  0.030566  0.000000
# 7    0.107403  0.075441  0.091284  0.092003  0.048201  0.199589  0.195689
# 8    0.164674  0.214469  0.173308  0.168647  0.194015  0.070661  0.101203
# 9    0.069470  0.222328  0.082608  0.084161  0.181582  0.121372  0.093282
# 10   0.017606  0.160078  0.020826  0.024226  0.119238  0.126194  0.109081
# 959  0.230906  0.127353  0.098367 ...        NaN       NaN       NaN
# 960  0.097798  0.207519  0.235344 ...        NaN       NaN       NaN
# 961  0.142031  0.195079  0.260936 ...        NaN       NaN       NaN
# 962  0.075131  0.180404  0.195294 ...        NaN       NaN       NaN
# 963  0.295918  0.097197  0.196772 ...        NaN       NaN       NaN
# 964  0.150631  0.284629  0.310059 ...        NaN       NaN       NaN
# 965  0.123415  0.251069  0.276897 ...        NaN       NaN       NaN
# 966  0.321258  0.173063  0.178616 ...        NaN       NaN       NaN
# 967  0.210433  0.063126  0.132026 ...        NaN       NaN       NaN
# 968  0.314656  0.331942  0.440798 ...        NaN       NaN       NaN
# 969  0.207969  0.110011  0.092554 ...        NaN       NaN       NaN
# 970  0.098102  0.231533  0.091394 ...        NaN       NaN       NaN
# 971  0.141122  0.106213  0.097625 ...        NaN       NaN       NaN
# 972  0.199174  0.133093  0.067927 ...        NaN       NaN       NaN
# 973  0.512088  0.285233  0.447252 ...        NaN       NaN       NaN
# 974  0.297993  0.089168  0.207769 ...        NaN       NaN       NaN
# 975  0.149519  0.290565  0.311170 ...   0.000000       NaN       NaN
# 976  0.395113  0.281873  0.229703 ...   0.522397  0.000000       NaN
# 977  0.076145  0.232559  0.232986 ...   0.078184  0.446525  0.000000
# 978  0.098204  0.245246  0.255571 ...   0.055788  0.467307  0.022941
# 979  0.117747  0.295355  0.286526 ...   0.047045  0.506259  0.063756
# 980  0.144274  0.186193  0.257118 ...   0.110080  0.441519  0.086468
# 981  0.041763  0.224015  0.201645 ...   0.110860  0.419941  0.034658
# 982  0.283922  0.088708  0.186344 ...   0.371070  0.200813  0.305982
# 983  0.144887  0.240392  0.287541 ...   0.055909  0.486284  0.070025
# 984  0.422881  0.197597  0.369893 ...   0.455664  0.347461  0.414320
#
#           978       979       980       981       982       983  984
# 0         NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 1         NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 2         NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 3         NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 4         NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 5         NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 6         NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 7         NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 8         NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 9         NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 10        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 11        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 12        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 13        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 14        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 15        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 16        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 17        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 18        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 19        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 20        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 21        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 22        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 23        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 24        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 25        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 26        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 27        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 28        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 29        NaN       NaN       NaN       NaN       NaN       NaN  NaN
# ..        ...       ...       ...       ...       ...       ...  ...
# 955       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 956       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 957       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 958       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 959       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 960       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 961       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 962       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 963       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 964       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 965       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 966       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 967       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 968       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 969       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 970       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 971       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 972       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 973       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 974       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 975       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 976       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 977       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 978  0.000000       NaN       NaN       NaN       NaN       NaN  NaN
# 979  0.051141  0.000000       NaN       NaN       NaN       NaN  NaN
# 980  0.082808  0.131054  0.000000       NaN       NaN       NaN  NaN
# 981  0.057255  0.086342  0.107873  0.000000       NaN       NaN  NaN
# 982  0.321772  0.369736  0.271376  0.290674  0.000000       NaN  NaN
# 983  0.052405  0.086902  0.055533  0.103196  0.323938  0.000000  NaN
# 984  0.421562  0.472628  0.345718  0.413285  0.188656  0.400161  0.0
#
# [985 rows x 985 columns]

# %%
def kallnn(k,vec1, filesac):
    knnk = pd.Series([vec1])
    ind1 = filesac.street[filesac.street == vec1].index
    col=pd.Series()
    for i in range (0,len(filesac.index)):
        series1=filesac.loc[ind1]
        series2=filesac.loc[i]
        d = my_knn(series1,series2)
        if d != 0:
            col = col.set_value(i,d)
    col.sort()
    kseries= col.head(k).index
    for elements in kseries:
        foo = pd.Series([filesac.street[elements] ])
        serieses = [knnk,foo]
        knnk = pd.concat(serieses)
    return(knnk)
kallnn(6,'7511 OAKVALE CT',filesac)
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:11: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
# 0        7511 OAKVALE CT
# 0        3604 KODIAK WAY
# 0     3729 BAINBRIDGE DR
# 0         7204 THOMAS DR
# 0      7226 LARCHMONT DR
# 0    3536 SUN MAIDEN WAY
# 0      7381 WASHBURN WAY
# dtype: object

# %%
def four_nn(filesac):
    names = pd.Series(['4882 BANDALIN WAY','7511 OAKVALE CT','7731 MASTERS ST','4925 PERCHERON DR','4727 SAVOIE WAY','3228 BAGGAN CT','8515 DARTFORD DR','2460 EL ROCCO WAY','5840 WALERGA RD','923 FULTON AVE','4030 BROADWAY','6485 LAGUNA MIRAGE LN','8758 LEMAS RD','1140 EDMONTON DR','1890 GENEVA PL'])
    knn4 = pd.DataFrame()
    for name in names:
        ind1 = filesac.street[filesac.street == name].index
        col=pd.Series()
        for i in range (0,len(filesac.index)):
            series1=filesac.loc[ind1]
            series2=filesac.loc[i]
            d = my_knn(series1,series2)
            col = col.set_value(i,d)
        col.sort()
        a,b,c,d,e= col.head(5).index
        knn4[name]=([filesac.street[b],filesac.street[c],filesac.street[d],filesac.street[e]])
    return(knn4)
four_nn(filesac)
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:12: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#         4882 BANDALIN WAY     7511 OAKVALE CT        7731 MASTERS ST  \
# 0         5 BISHOPGATE CT     3604 KODIAK WAY            18 OLLIE CT
# 1  4621 COUNTRY SCENE WAY  3729 BAINBRIDGE DR        8442 KEUSMAN ST
# 2           8 LA ROCAS CT      7204 THOMAS DR  6930 HAMPTON COVE WAY
# 3          4867 LAGUNA DR   7226 LARCHMONT DR        8253 KEEGAN WAY
#
#        4925 PERCHERON DR               4727 SAVOIE WAY       3228 BAGGAN CT  \
# 0        4804 NORIKER DR               230 CANDELA CIR       7895 CABER WAY
# 1        4620 WELERA WAY   4800 WESTLAKE PKWY Unit 410  3536 SUN MAIDEN WAY
# 2  5201 BLOSSOM RANCH DR  4800 WESTLAKE PKWY Unit 2109     3318 DAVIDSON DR
# 3     8986 HAFLINGER WAY             241 LANFRANCO CIR     3305 RIO ROCA CT
#
#    8515 DARTFORD DR   2460 EL ROCCO WAY         5840 WALERGA RD  \
# 0  8495 DARTFORD DR     2361 LA LOMA DR  5754 WALERGA RD Unit 4
# 1   8593 DERLIN WAY   2219 EL CANTO CIR     4533 LOCH HAVEN WAY
# 2   8442 KEUSMAN ST  10245 LOS PALOS DR     4524 LOCH HAVEN WAY
# 3         9 WIND CT      2319 THORES ST     5672 HILLSDALE BLVD
#
#              923 FULTON AVE      4030 BROADWAY  6485 LAGUNA MIRAGE LN  \
# 0          2442 LARKSPUR LN       3118 42ND ST  6344 LAGUNA MIRAGE LN
# 1           1139 CLINTON RD       3348 40TH ST    9185 CERROLINDA CIR
# 2  739 E WOODSIDE LN Unit E      4180 12TH AVE        9080 FRESCA WAY
# 3           2340 HURLEY WAY  2450 SAN JOSE WAY         7005 TIANT WAY
#
#             8758 LEMAS RD      1140 EDMONTON DR     1890 GENEVA PL
# 0   8788 LA MARGARITA WAY  1158 SAN IGNACIO WAY    1528 HESKET WAY
# 1       8032 DUSENBERG CT          9 PASTURE CT    3128 VIA GRANDE
# 2      8167 DERBY PARK CT    2956 DAVENPORT WAY  3025 EL PRADO WAY
# 3  8728 CRYSTAL RIVER WAY       1035 MILLET WAY    2340 HURLEY WAY

# %%
def five_nn(filesac):
    knn5 = pd.DataFrame()
    names = pd.Series(['4882 BANDALIN WAY','7511 OAKVALE CT','7731 MASTERS ST','4925 PERCHERON DR','4727 SAVOIE WAY','3228 BAGGAN CT','8515 DARTFORD DR','2460 EL ROCCO WAY','5840 WALERGA RD','923 FULTON AVE','4030 BROADWAY','6485 LAGUNA MIRAGE LN','8758 LEMAS RD','1140 EDMONTON DR','1890 GENEVA PL'])
    for name in names:
        ind1 = filesac.street[filesac.street == name].index
        col=pd.Series()
        for i in range (0,len(filesac.index)):
            series1=filesac.loc[ind1]
            series2=filesac.loc[i]
            d = my_knn(series1,series2)
            col = col.set_value(i,d)
        col.sort()
        a,b,c,d,e,f= col.head(6).index
        knn5[name]=([filesac.street[b],filesac.street[c],filesac.street[d],filesac.street[e],filesac.street[f]])
    return (knn5)
five_nn(filesac)
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:12: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#         4882 BANDALIN WAY      7511 OAKVALE CT        7731 MASTERS ST  \
# 0         5 BISHOPGATE CT      3604 KODIAK WAY            18 OLLIE CT
# 1  4621 COUNTRY SCENE WAY   3729 BAINBRIDGE DR        8442 KEUSMAN ST
# 2           8 LA ROCAS CT       7204 THOMAS DR  6930 HAMPTON COVE WAY
# 3          4867 LAGUNA DR    7226 LARCHMONT DR        8253 KEEGAN WAY
# 4    8101 PORT ROYALE WAY  3536 SUN MAIDEN WAY       8515 DARTFORD DR
#
#        4925 PERCHERON DR               4727 SAVOIE WAY       3228 BAGGAN CT  \
# 0        4804 NORIKER DR               230 CANDELA CIR       7895 CABER WAY
# 1        4620 WELERA WAY   4800 WESTLAKE PKWY Unit 410  3536 SUN MAIDEN WAY
# 2  5201 BLOSSOM RANCH DR  4800 WESTLAKE PKWY Unit 2109     3318 DAVIDSON DR
# 3     8986 HAFLINGER WAY             241 LANFRANCO CIR     3305 RIO ROCA CT
# 4      9677 PILLITERI CT             14 CASA VATONI PL      3604 KODIAK WAY
#
#    8515 DARTFORD DR   2460 EL ROCCO WAY         5840 WALERGA RD  \
# 0  8495 DARTFORD DR     2361 LA LOMA DR  5754 WALERGA RD Unit 4
# 1   8593 DERLIN WAY   2219 EL CANTO CIR     4533 LOCH HAVEN WAY
# 2   8442 KEUSMAN ST  10245 LOS PALOS DR     4524 LOCH HAVEN WAY
# 3         9 WIND CT      2319 THORES ST     5672 HILLSDALE BLVD
# 4   24 WINDCHIME CT    2636 TRONERO WAY      5937 YORK GLEN WAY
#
#              923 FULTON AVE      4030 BROADWAY  6485 LAGUNA MIRAGE LN  \
# 0          2442 LARKSPUR LN       3118 42ND ST  6344 LAGUNA MIRAGE LN
# 1           1139 CLINTON RD       3348 40TH ST    9185 CERROLINDA CIR
# 2  739 E WOODSIDE LN Unit E      4180 12TH AVE        9080 FRESCA WAY
# 3           2340 HURLEY WAY  2450 SAN JOSE WAY         7005 TIANT WAY
# 4           1528 HESKET WAY       3920 39TH ST    5529 LAGUNA PARK DR
#
#             8758 LEMAS RD      1140 EDMONTON DR     1890 GENEVA PL
# 0   8788 LA MARGARITA WAY  1158 SAN IGNACIO WAY    1528 HESKET WAY
# 1       8032 DUSENBERG CT          9 PASTURE CT    3128 VIA GRANDE
# 2      8167 DERBY PARK CT    2956 DAVENPORT WAY  3025 EL PRADO WAY
# 3  8728 CRYSTAL RIVER WAY       1035 MILLET WAY    2340 HURLEY WAY
# 4       8909 BILLFISH WAY     2847 BELGRADE WAY   2442 LARKSPUR LN

# %% [markdown]
# ## PART 3 / Data Exploration
#
# For this part we will be using the data from the [Salt Lake City water usage dataset (by block)](http://www.civicdata.io/dataset/slc_water_usage_1/resource/a2bc8285-d9ef-45ca-ae86-bf735bc5011a).  This dataset includes information about water consumption for 2016.
#
# ## Explore the data:
#
# ### &#167; How many different property types are described in this data?
# ### &#167; How many much of consumption data is less than 0?
# ### &#167; Produce a histogram of the monthly consumption for all property types?

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import numpy as np
from StringIO import StringIO
import math
from scipy import stats  as sp

def run():
    saltlake = pd.read_csv('https://raw.githubusercontent.com/chaithanya1945/hmwork/master/a2bc8285-d9ef-45ca-ae86-bf735bc5011a.csv')
    return(saltlake)
run()
# Out:
#          _id    yr  mo   tract  block                           descr  \
# 0          1  2016   1  100100   1000  Business
# 1          2  2016   1  100100   1003  Business
# 2          3  2016   1  100100   1004  Business
# 3          4  2016   1  100100   1004  Miscellaneous
# 4          5  2016   1  100100   1006  Business
# 5          6  2016   1  100100   1006  Single Residence
# 6          7  2016   1  100100   1008  Industry
# 7          8  2016   1  100100   1009  Business
# 8          9  2016   1  100100   1009  Industry
# 9         10  2016   1  100100   1009  Single Residence
# 10        11  2016   1  100100   1010  Miscellaneous
# 11        12  2016   1  100100   1010  Single Residence
# 12        13  2016   1  100100   1011  Business
# 13        14  2016   1  100100   1011  Industry
# 14        15  2016   1  100100   1011  Single Residence
# 15        16  2016   1  100100   1012  Business
# 16        17  2016   1  100100   1013  Single Residence
# 17        18  2016   1  100100   1014  Business
# 18        19  2016   1  100100   1016  Industry
# 19        20  2016   1  100100   1017  Business
# 20        21  2016   1  100100   1017  Industry
# 21        22  2016   1  100100   1018  Business
# 22        23  2016   1  100100   1018  Duplex
# 23        24  2016   1  100100   1018  Fourplex
# 24        25  2016   1  100100   1018  Single Residence
# 25        26  2016   1  100100   1019  Business
# 26        27  2016   1  100100   1019  Restaurant
# 27        28  2016   1  100100   1021  Industry
# 28        29  2016   1  100100   1022  Business
# 29        30  2016   1  100100   1022  Industry
# ...      ...   ...  ..     ...    ...                             ...
# 45219  45220  2016   7  980000   1029  Business
# 45220  45221  2016   7  980000   1030  Business
# 45221  45222  2016   7  980000   1030  Hotel or Motel
# 45222  45223  2016   7  980000   1030  Industry
# 45223  45224  2016   7  980000   1030  Miscellaneous
# 45224  45225  2016   7  980000   1030  Parks & Municipals
# 45225  45226  2016   7  980000   1031  Business
# 45226  45227  2016   7  980000   1031  Miscellaneous
# 45227  45228  2016   7  980000   1033  Business
# 45228  45229  2016   7  980000   1033  Miscellaneous
# 45229  45230  2016   7  980000   1034  Business
# 45230  45231  2016   7  980000   1034  Miscellaneous
# 45231  45232  2016   7  980000   1035  Business
# 45232  45233  2016   7  980000   1035  Miscellaneous
# 45233  45234  2016   7  980000   1036  Business
# 45234  45235  2016   7  980000   1036  Miscellaneous
# 45235  45236  2016   7  980000   1036  Parks & Municipals
# 45236  45237  2016   7  980000   1037  Business
# 45237  45238  2016   7  980000   1038  Business
# 45238  45239  2016   7  980000   1038  Miscellaneous
# 45239  45240  2016   7  980000   1039  Business
# 45240  45241  2016   7  980000   1039  Industry
# 45241  45242  2016   7  980000   1039  Miscellaneous
# 45242  45243  2016   7  980000   1041  Parks & Municipals
# 45243  45244  2016   7  980000   1042  Business
# 45244  45245  2016   7  980000   1043  Business
# 45245  45246  2016   7  980000   1043  Miscellaneous
# 45246  45247  2016   7  980000   1045  Hotel or Motel
# 45247  45248  2016   7  980000   1045  Miscellaneous
# 45248  45249  2016   7  980000   1045  Parks & Municipals
#
#        consumption  connections
# 0                0            2
# 1                2            1
# 2              606           19
# 3                0            2
# 4              224           12
# 5                6            2
# 6                0            1
# 7               76           10
# 8               26            2
# 9                8            4
# 10               0            1
# 11              33            8
# 12               0            1
# 13               2            1
# 14              28            9
# 15               5            2
# 16               0            4
# 17               0            1
# 18             760            3
# 19              28            5
# 20             112            2
# 21              66            4
# 22              21            2
# 23              10            1
# 24               4            1
# 25             308           16
# 26              33            1
# 27           80357            5
# 28             598            4
# 29               0            2
# ...            ...          ...
# 45219          251            2
# 45220        22382           58
# 45221        15517           42
# 45222          357            5
# 45223          162            7
# 45224            0            1
# 45225         1199            7
# 45226         1163            1
# 45227         3605            5
# 45228         1370            4
# 45229         6154           13
# 45230            0            1
# 45231         6126           25
# 45232         2024            3
# 45233         2859            5
# 45234         1283            1
# 45235            0            1
# 45236          121            1
# 45237        10632           22
# 45238         1568            2
# 45239         4824            8
# 45240          383            2
# 45241         1674            4
# 45242        27355            5
# 45243         2726           11
# 45244          153            1
# 45245            4            2
# 45246         1467            2
# 45247            0            1
# 45248          199            1
#
# [45249 rows x 8 columns]

# %%
saltlake = pd.read_csv('https://raw.githubusercontent.com/chaithanya1945/hmwork/master/a2bc8285-d9ef-45ca-ae86-bf735bc5011a.csv')

# %%
def lessthanzero(saltlake):
    consumption = saltlake['consumption']
    consumption_less = consumption[consumption < 0]
    print consumption_less.size
    return(consumption_less.size)

# %%
lessthanzero(saltlake)
# Out:
# 266
# 266

# %%
def monthly(saltlake):
    types = saltlake['descr']
    consumption = saltlake['consumption']
    for i, group in saltlake.groupby(['descr']):
        plt.hist(group.consumption)
        plt.xlabel(i)
        plt.show()

# %%
monthly(saltlake)

# %% [markdown]
# ## Fix the data
# There are some data in the input that needs work. In particular, the property descriptions have issues.  Fix them (**hint:** explore [strip()]() and [lower()]()).  Also please remove all data points that are out of spec, that is connections less than 0 and consumption less than 0.
#
# ### &#167; How many data points do you now have?
# ### &#167; Show the descriptive stats for this new fixed data: For consumption and connections only, what is the mean, media, min and max?
# ### &#167; Normalize the data using z-score normalization for connection and consumption.  Show the `head()` and `tail()` of the new values.

# %%
def data(saltlake):
    saltlake.loc[saltlake.consumption < 0 ] = np.nan
    saltlake.loc[saltlake.connections < 0 ] = np.nan
    saltlake =saltlake.dropna(how='any')
    return(saltlake)

# %%
data(saltlake)
# Out:
#            _id      yr   mo     tract   block                           descr  \
# 0          1.0  2016.0  1.0  100100.0  1000.0  Business
# 1          2.0  2016.0  1.0  100100.0  1003.0  Business
# 2          3.0  2016.0  1.0  100100.0  1004.0  Business
# 3          4.0  2016.0  1.0  100100.0  1004.0  Miscellaneous
# 4          5.0  2016.0  1.0  100100.0  1006.0  Business
# 5          6.0  2016.0  1.0  100100.0  1006.0  Single Residence
# 6          7.0  2016.0  1.0  100100.0  1008.0  Industry
# 7          8.0  2016.0  1.0  100100.0  1009.0  Business
# 8          9.0  2016.0  1.0  100100.0  1009.0  Industry
# 9         10.0  2016.0  1.0  100100.0  1009.0  Single Residence
# 10        11.0  2016.0  1.0  100100.0  1010.0  Miscellaneous
# 11        12.0  2016.0  1.0  100100.0  1010.0  Single Residence
# 12        13.0  2016.0  1.0  100100.0  1011.0  Business
# 13        14.0  2016.0  1.0  100100.0  1011.0  Industry
# 14        15.0  2016.0  1.0  100100.0  1011.0  Single Residence
# 15        16.0  2016.0  1.0  100100.0  1012.0  Business
# 16        17.0  2016.0  1.0  100100.0  1013.0  Single Residence
# 17        18.0  2016.0  1.0  100100.0  1014.0  Business
# 18        19.0  2016.0  1.0  100100.0  1016.0  Industry
# 19        20.0  2016.0  1.0  100100.0  1017.0  Business
# 20        21.0  2016.0  1.0  100100.0  1017.0  Industry
# 21        22.0  2016.0  1.0  100100.0  1018.0  Business
# 22        23.0  2016.0  1.0  100100.0  1018.0  Duplex
# 23        24.0  2016.0  1.0  100100.0  1018.0  Fourplex
# 24        25.0  2016.0  1.0  100100.0  1018.0  Single Residence
# 25        26.0  2016.0  1.0  100100.0  1019.0  Business
# 26        27.0  2016.0  1.0  100100.0  1019.0  Restaurant
# 27        28.0  2016.0  1.0  100100.0  1021.0  Industry
# 28        29.0  2016.0  1.0  100100.0  1022.0  Business
# 29        30.0  2016.0  1.0  100100.0  1022.0  Industry
# ...        ...     ...  ...       ...     ...                             ...
# 45219  45220.0  2016.0  7.0  980000.0  1029.0  Business
# 45220  45221.0  2016.0  7.0  980000.0  1030.0  Business
# 45221  45222.0  2016.0  7.0  980000.0  1030.0  Hotel or Motel
# 45222  45223.0  2016.0  7.0  980000.0  1030.0  Industry
# 45223  45224.0  2016.0  7.0  980000.0  1030.0  Miscellaneous
# 45224  45225.0  2016.0  7.0  980000.0  1030.0  Parks & Municipals
# 45225  45226.0  2016.0  7.0  980000.0  1031.0  Business
# 45226  45227.0  2016.0  7.0  980000.0  1031.0  Miscellaneous
# 45227  45228.0  2016.0  7.0  980000.0  1033.0  Business
    types = saltlake['descr']
    typesclean = types.drop_duplicates()
    typenumber = typesclean.size
    return (typenumber)
propertytypes(saltlake)
# Out:
# 13

# %%
def descriptive(saltlake):
    consumption = saltlake['consumption']
    connections = saltlake['connections']
    consumption_min = consumption.min()
    consumption_max = consumption.max()
    consumption_mean = consumption.mean()
    consumption_median = consumption.median()

    connections_min = connections.min()
    connections_max = connections.max()
    connections_mean = connections.mean()
    connections_median = connections.median()
    print consumption_max,consumption_min,consumption_mean,consumption_median
    print connections_max,connections_min,connections_mean,connections_median
descriptive(saltlake)
# Out:
# 140070.0 0.0 262.131427428 58.0
# 201.0 1.0 8.32396683191 3.0

# %%
def z_score(saltlake):
    consumption = saltlake['consumption']
    connections = saltlake['connections']
    consumption_z_score = ((consumption - consumption.mean())/consumption.std(ddof=0))
    connections_z_score = ((connections - connections.mean())/connections.std(ddof=0))
    print consumption_z_score.head(),consumption_z_score.tail()
    print connections_z_score.head(),connections_z_score.tail()

# %%
z_score(saltlake)
# Out:
# 0   -0.149932
# 1   -0.148788
# 2    0.196683
# 3   -0.149932
# 4   -0.021810
# Name: consumption, dtype: float64 45244   -0.062420
# 45245   -0.147644
# 45246    0.689151
# 45247   -0.149932
# 45248   -0.036109
# Name: consumption, dtype: float64
# 0   -0.530645
# 1   -0.614555
# 2    0.895827
# 3   -0.530645
# 4    0.308456
# Name: connections, dtype: float64 45244   -0.614555
# 45245   -0.530645
# 45246   -0.530645
# 45247   -0.614555
# 45248   -0.614555
# Name: connections, dtype: float64

# %% [markdown]
# ## Explore relationships
#
# ### &#167; Plot the connections (x-axis) to consumption (y-axis) in scatter plot.  Is there a relationship?

# %%
def plotcon(saltlake):
    consumption = saltlake['consumption']
    connections = saltlake['connections']
    plt.plot(connections,consumption,'o')
    plt.xlabel('connections')
    plt.ylabel('consumption')
    plt.suptitle('connections to consumption')
    plt.show()

# %% [markdown]
# ### &#167; Compute the Pearson's _r_ correlation between these two?  Does it confirm what you see?
# * You will need to investigate the [scipy Pearson's _r_ for this part](http://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.pearsonr.html).

# %%
def pearson(saltlake):
    consumption = saltlake['consumption']
    connections = saltlake['connections']
    pearson=sp.pearsonr(connections,consumption)
    return(pearson)

# %% [markdown]
# ### &#167; Group the data by month and by property type and show the bar plot of this for the year-to-date day (January to July).
#
# * You will need to read up on the [groupby]() function in Pandas for the next few questions.
# * Also read up on plotting/visualizing in Pandas.

# %%
def group(saltlake):
    months = saltlake.groupby(['mo'])
    typegroup = saltlake.groupby(['descr'])

# %% [markdown]
# ## BONUS
#
# ## This analysis optional, but you will receive 1 bonus point for each question you answer below.
#
# ### _Water consumption rises dramatically in June and July -- let's explore why?_
# ### &#167; Analyze the data for May, June and July and produce a bar plot of the consumpution over those three months.
# ### &#167; Explain what you see.  Of course, during the summer months, the temperatures are higher and thus water consumption would naturally go up, but given what you see in the plot, what else is going on?
#
# * _Hints_: You will need to understand how to use [aggregate()](http://pandas.pydata.org/pandas-docs/stable/groupby.html#aggregation) and maybe [get_level_values()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.CategoricalIndex.get_level_values.html#pandas.CategoricalIndex.get_level_values).
